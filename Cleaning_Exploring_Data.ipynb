# %% [markdown]
# # Importing Libraries

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import pandas as pd
from pybaseball import pitching_stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP.models import ModelSpec as MS, summarize, poly

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Importing Data
# * Importing data from pybaseball
# * Selecting variables that could be useed in regression models

# %%
data = pitching_stats(2024,2024)
data.head()
# Out:
#      IDfg  Season          Name Team  Age   W  L  WAR   ERA   G  GS  CG  ShO  \
# 0   10603    2024    Chris Sale  ATL   35  18  3  6.4  2.38  29  29   0    0
# 1   22267    2024  Tarik Skubal  DET   27  18  4  6.0  2.39  31  31   0    0
# 2   10310    2024  Zack Wheeler  PHI   34  16  7  5.4  2.57  32  32   0    0
# 11  21846    2024   Cole Ragans  KCR   26  11  9  4.9  3.14  32  32   1    0
# 9   12447    2024     Seth Lugo  KCR   34  16  9  4.7  3.00  33  33   1    0
#
#     SV  BS     IP  TBF    H   R  ER  HR  BB  IBB  HBP  WP  BK   SO   GB   FB  \
# 0    0   0  177.2  702  141  48  47   9  39    0    8   4   1  225  191  143
# 1    0   0  192.0  753  142  54  51  15  35    0    9   2   0  228  218  171
# 2    0   0  200.0  787  139  62  57  20  52    0    8   8   0  224  213  195
# 11   0   0  186.1  762  146  71  65  15  67    1    6  11   0  223  187  186
# 9    0   0  206.2  836  177  75  69  16  48    1    9   4   0  181  261  217
#
#      LD  IFFB  Balls  Strikes  Pitches   RS  IFH  BU  BUH    K/9  BB/9  K/BB  \
# 0    92     8    925     1893     2818  126    5   4    0  11.40  1.98  5.77
# 1    88    22    883     1985     2868  134   13   4    2  10.69  1.64  6.51
# 2    92    27   1079     2057     3136  118   17   3    0  10.08  2.34  4.31
# 11   86    18   1138     1980     3118   86   10   7    2  10.77  3.24  3.33
# 9   113    18   1079     2033     3112  109   22   7    4   7.88  2.09  3.77
#
#      H/9  HR/9    AVG  WHIP  BABIP   LOB%   FIP  GB/FB    LD%    GB%    FB%  \
# 0   7.14  0.46  0.215  1.01  0.314  0.798  2.09   1.34  0.216  0.448  0.336
# 1   6.66  0.70  0.200  0.92  0.273  0.800  2.49   1.27  0.184  0.457  0.358
# 2   6.26  0.90  0.191  0.96  0.246  0.801  3.13   1.09  0.184  0.426  0.390
# 11  7.05  0.72  0.212  1.14  0.290  0.747  2.99   1.01  0.187  0.407  0.405
# 9   7.71  0.70  0.227  1.09  0.277  0.751  3.25   1.20  0.191  0.442  0.367
#
#     IFFB%  HR/FB   IFH%   BUH%  Starting  Start-IP  Relieving  Relief-IP  \
# 0   0.056  0.063  0.026  0.000      56.3     177.2        NaN        NaN
# 1   0.129  0.088  0.060  0.500      53.3     192.0        NaN        NaN
# 2   0.138  0.103  0.080  0.000      49.1     200.0        NaN        NaN
# 11  0.097  0.081  0.053  0.286      44.5     186.1        NaN        NaN
# 9   0.083  0.074  0.084  0.571      43.4     206.2        NaN        NaN
#
#      RAR Dollars  tERA  xFIP   WPA   -WPA   +WPA   RE24   REW   pLI  inLI  \
# 0   56.3   $51.4  2.45  2.64  4.04  -9.08  13.12  41.11  4.24  0.95  0.90
# 1   53.3   $47.7  2.51  2.83  4.29  -9.26  13.55  40.04  4.20  0.92  0.92
# 2   49.1   $43.1  3.12  3.30  3.95 -10.39  14.35  39.13  4.00  0.92  0.90
# 11  44.5   $38.8  3.12  3.46  2.56 -12.19  14.75  25.74  2.57  1.03  0.98
# 9   43.4   $37.4  3.49  3.83  3.58 -11.97  15.55  35.57  3.61  0.98  0.92
#
#     gmLI  exLI  Pulls  WPA/LI  Clutch  FB% 2   FBv    SL%   SLv    CT%   CTv  \
# 0   0.87  0.83     29    4.37   -0.11  0.455  94.8  0.403  78.7    NaN   NaN
# 1   0.88  0.95     31    4.17    0.47  0.539  96.8  0.146  88.8    NaN   NaN
# 2   0.87  0.78     32    3.43    0.84  0.605  95.1  0.123  85.0  0.098  91.1
# 11  0.88  1.27     31    2.73   -0.23  0.418  95.4  0.133  86.1  0.108  91.0
# 9   0.87  1.11     32    3.43    0.23  0.439  92.2  0.230  82.6  0.073  89.9
#
#       CB%   CBv    CH%   CHv    SF%   SFv  KN%  KNv    XX%  PO%   wFB   wSL  \
# 0     NaN   NaN  0.142  86.9    NaN   NaN  NaN  NaN  0.001  NaN  -5.5  24.4
# 1   0.042  78.5  0.273  86.3    NaN   NaN  NaN  NaN  0.001  NaN  25.0   3.0
# 2   0.101  81.8    NaN   NaN  0.073  86.2  NaN  NaN  0.001  NaN  28.0   4.2
# 11  0.104  80.8  0.237  84.8    NaN   NaN  NaN  NaN  0.000  NaN  10.5  -0.6
# 9   0.166  79.8  0.061  87.5  0.031  85.8  NaN  NaN  0.001  NaN   7.1   3.5
#
#     wCT  wCB   wCH  wSF  wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  \
# 0   NaN  NaN  12.1  NaN  NaN  -0.43   2.15    NaN    NaN   3.02    NaN    NaN
# 1   NaN  1.6   8.6  NaN  NaN   1.62   0.71    NaN   1.32   1.10    NaN    NaN
# 2   0.3 -2.3   NaN  3.7  NaN   1.48   1.08   0.10  -0.73    NaN   1.62    NaN
# 11 -1.0  3.1  10.6  NaN  NaN   0.81  -0.14  -0.29   0.96   1.43    NaN    NaN
# 9   5.8  5.3  -1.3  0.7  NaN   0.52   0.49   2.54   1.02  -0.70   0.68    NaN
#
#     O-Swing%  Z-Swing%  Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  \
# 0      0.369     0.646   0.490       0.576       0.812     0.711  0.435
# 1      0.352     0.698   0.516       0.566       0.801     0.717  0.475
# 2      0.364     0.713   0.511       0.641       0.822     0.747  0.420
# 11     0.331     0.716   0.488       0.577       0.791     0.705  0.409
# 9      0.314     0.661   0.463       0.634       0.897     0.795  0.430
#
#     F-Strike%  SwStr%  HLD  SD  MD  ERA-  FIP-  xFIP-     K%    BB%  SIERA  \
# 0       0.694   0.141    0   0   0    57    53     66  0.321  0.056   2.80
# 1       0.687   0.146    0   0   0    59    60     68  0.303  0.046   2.89
# 2       0.642   0.129    0   0   0    61    76     82  0.285  0.066   3.32
# 11      0.587   0.144    0   0   0    76    73     84  0.293  0.088   3.49
# 9       0.644   0.095    0   0   0    73    79     93  0.217  0.057   3.94
#
#     RS/9   E-F  FA% (sc)  FT% (sc)  FC% (sc)  FS% (sc)  FO% (sc)  SI% (sc)  \
# 0   6.38  0.30     0.378       NaN       NaN       NaN       NaN     0.072
# 1   6.28 -0.10     0.332       NaN       NaN       NaN       NaN     0.205
# 2   5.31 -0.56     0.416       NaN     0.093     0.074       NaN     0.192
# 11  4.15  0.14     0.418       NaN     0.113       NaN       NaN       NaN
# 9   4.75 -0.24     0.240       NaN     0.082     0.026       NaN     0.185
#
#     SL% (sc)  CU% (sc)  KC% (sc)  EP% (sc)  CH% (sc)  SC% (sc)  KN% (sc)  \
# 0      0.403       NaN       NaN       NaN     0.147       NaN       NaN
# 1      0.149       NaN     0.042       NaN     0.271       NaN       NaN
# 2      0.125     0.100       NaN       NaN       NaN       NaN       NaN
# 11     0.128       NaN     0.104       NaN     0.237       NaN       NaN
# 9      0.135     0.262       NaN       NaN     0.069       NaN       NaN
#
#     UN% (sc)  vFA (sc)  vFT (sc)  vFC (sc)  vFS (sc)  vFO (sc)  vSI (sc)  \
# 0        NaN      94.8       NaN       NaN       NaN       NaN      94.2
# 1        NaN      96.8       NaN       NaN       NaN       NaN      96.6
# 2        NaN      95.3       NaN      91.1      86.1       NaN      94.6
# 11       NaN      95.4       NaN      90.7       NaN       NaN       NaN
# 9        NaN      92.2       NaN      90.1      85.7       NaN      92.1
#
#     vSL (sc)  vCU (sc)  vKC (sc)  vEP (sc)  vCH (sc)  vSC (sc)  vKN (sc)  \
# 0       78.6       NaN       NaN       NaN      87.1       NaN       NaN
# 1       88.7       NaN      78.5       NaN      86.3       NaN       NaN
# 2       84.9      81.8       NaN       NaN       NaN       NaN       NaN
# 11      86.0       NaN      80.8       NaN      84.8       NaN       NaN
# 9       85.2      79.4       NaN       NaN      87.4       NaN       NaN
#
#     FA-X (sc)  FT-X (sc)  FC-X (sc)  FS-X (sc)  FO-X (sc)  SI-X (sc)  \
# 0         9.5        NaN        NaN        NaN        NaN       11.1
# 1         4.2        NaN        NaN        NaN        NaN        8.9
# 2        -6.2        NaN       -0.3       -7.9        NaN      -10.4
# 11        7.6        NaN        1.0        NaN        NaN        NaN
# 9        -4.2        NaN       -0.2       -6.4        NaN       -9.1
#
#     SL-X (sc)  CU-X (sc)  KC-X (sc)  EP-X (sc)  CH-X (sc)  SC-X (sc)  \
# 0        -5.3        NaN        NaN        NaN       10.1        NaN
# 1        -0.8        NaN       -2.8        NaN        9.0        NaN
# 2         4.7        4.2        NaN        NaN        NaN        NaN
# 11       -0.1        NaN       -5.4        NaN        9.4        NaN
# 9         3.6        8.6        NaN        NaN       -8.8        NaN
#
#     KN-X (sc)  FA-Z (sc)  FT-Z (sc)  FC-Z (sc)  FS-Z (sc)  FO-Z (sc)  \
# 0         NaN        5.8        NaN        NaN        NaN        NaN
# 1         NaN        9.6        NaN        NaN        NaN        NaN
# 2         NaN        8.4        NaN        4.8        3.3        NaN
# 11        NaN       10.3        NaN        5.9        NaN        NaN
# 9         NaN        8.9        NaN        6.7        2.8        NaN
#
#     SI-Z (sc)  SL-Z (sc)  CU-Z (sc)  KC-Z (sc)  EP-Z (sc)  CH-Z (sc)  \
# 0         1.6       -2.9        NaN        NaN        NaN        0.2
# 1         7.3        3.8        NaN       -4.5        NaN        3.8
# 2         3.9        2.3       -4.9        NaN        NaN        NaN
# 11        NaN        0.6        NaN       -7.0        NaN        7.5
# 9         5.0        2.3       -6.8        NaN        NaN        2.8
#
#     SC-Z (sc)  KN-Z (sc)  wFA (sc)  wFT (sc)  wFC (sc)  wFS (sc)  wFO (sc)  \
# 0         NaN        NaN      -1.3       NaN       NaN       NaN       NaN
# 1         NaN        NaN      17.3       NaN       NaN       NaN       NaN
# 2         NaN        NaN      11.1       NaN      -0.7       3.3       NaN
# 11        NaN        NaN      11.1       NaN       0.9       NaN       NaN
# 9         NaN        NaN       5.2       NaN       7.3       0.1       NaN
#
#     wSI (sc)  wSL (sc)  wCU (sc)  wKC (sc)  wEP (sc)  wCH (sc)  wSC (sc)  \
# 0       -4.0      24.6       NaN       NaN       NaN      12.3       NaN
# 1        7.3       3.3       NaN       1.5       NaN       8.7       NaN
# 2       15.7       4.0      -3.0       NaN       NaN       NaN       NaN
# 11       NaN      -1.4       NaN       2.9       NaN      10.6       NaN
# 9        3.7      -2.8      11.7       NaN       NaN       0.2       NaN
#
#     wKN (sc)  wFA/C (sc)  wFT/C (sc)  wFC/C (sc)  wFS/C (sc)  wFO/C (sc)  \
# 0        NaN       -0.12         NaN         NaN         NaN         NaN
# 1        NaN        1.84         NaN         NaN         NaN         NaN
# 2        NaN        0.88         NaN       -0.23        1.47         NaN
# 11       NaN        0.85         NaN        0.26         NaN         NaN
# 9        NaN        0.70         NaN        2.86        0.07         NaN
#
#     wSI/C (sc)  wSL/C (sc)  wCU/C (sc)  wKC/C (sc)  wEP/C (sc)  wCH/C (sc)  \
# 0        -1.99        2.16         NaN         NaN         NaN        2.97
# 1         1.25        0.78         NaN        1.26         NaN        1.13
# 2         2.68        1.04       -0.98         NaN         NaN         NaN
# 11         NaN       -0.34         NaN        0.90         NaN        1.43
# 9         0.65       -0.67        1.44         NaN         NaN        0.08
#
#     wSC/C (sc)  wKN/C (sc)  O-Swing% (sc)  Z-Swing% (sc)  Swing% (sc)  \
# 0          NaN         NaN          0.345          0.623        0.490
# 1          NaN         NaN          0.328          0.658        0.515
# 2          NaN         NaN          0.326          0.683        0.511
# 11         NaN         NaN          0.299          0.680        0.488
# 9          NaN         NaN          0.280          0.632        0.463
#
#     O-Contact% (sc)  Z-Contact% (sc)  Contact% (sc)  Zone% (sc)  Pace  \
# 0             0.536            0.802          0.712       0.520  19.6
# 1             0.493            0.801          0.716       0.566  16.6
# 2             0.582            0.821          0.747       0.519  18.6
# 11            0.534            0.783          0.705       0.495  17.8
# 9             0.570            0.888          0.795       0.520  16.4
#
#     RA9-WAR  BIP-Wins  LOB-Wins  FDP-Wins  Age Rng  K-BB%  Pull%  Cent%  \
# 0       7.0      -0.7       1.3       0.6  35 - 35  0.265  0.435  0.319
# 1       6.6       0.5       0.1       0.7  27 - 27  0.256  0.387  0.358
# 2       7.1       2.0      -0.2       1.7  34 - 34  0.219  0.350  0.406
# 11      4.8      -0.2       0.2       0.0  26 - 26  0.205  0.395  0.324
# 9       5.8       0.4       0.7       1.1  34 - 34  0.159  0.386  0.401
#
#     Oppo%  Soft%   Med%  Hard%  kwERA   TTO%  CH% (pi)  CS% (pi)  CU% (pi)  \
# 0   0.247  0.167  0.584  0.249   2.79  0.389     0.144       NaN       NaN
# 1   0.256  0.181  0.565  0.254   2.89  0.369     0.273       NaN     0.042
# 2   0.245  0.209  0.501  0.290   3.34  0.376       NaN       NaN     0.102
# 11  0.281  0.176  0.524  0.300   3.51  0.400     0.236       NaN     0.104
# 9   0.212  0.156  0.542  0.303   4.06  0.293     0.094       NaN     0.229
#
#     FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  SB% (pi)  SI% (pi)  SL% (pi)  \
# 0      0.378       NaN       NaN       NaN       NaN     0.074     0.403
# 1      0.332       NaN       NaN       NaN       NaN     0.206     0.148
# 2      0.413       NaN     0.073       NaN       NaN     0.191     0.220
# 11     0.419     0.114       NaN       NaN       NaN       NaN     0.127
# 9      0.236     0.090       NaN       NaN       NaN     0.186     0.165
#
#     XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  vFA (pi)  vFC (pi)  vFS (pi)  \
# 0        NaN      87.0       NaN       NaN      94.9       NaN       NaN
# 1        NaN      86.4       NaN      78.6      97.0       NaN       NaN
# 2        NaN       NaN       NaN      82.0      95.5       NaN      86.4
# 11       NaN      84.9       NaN      80.9      95.5      90.9       NaN
# 9        NaN      86.9       NaN      79.6      92.3      90.0       NaN
#
#     vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  vXX (pi)  CH-X (pi)  CS-X (pi)  \
# 0        NaN       NaN      94.1      78.7       NaN        9.4        NaN
# 1        NaN       NaN      96.7      88.9       NaN        8.6        NaN
# 2        NaN       NaN      94.8      87.8       NaN        NaN        NaN
# 11       NaN       NaN       NaN      86.1       NaN        9.3        NaN
# 9        NaN       NaN      92.2      83.9       NaN       -8.1        NaN
#
#     CU-X (pi)  FA-X (pi)  FC-X (pi)  FS-X (pi)  KN-X (pi)  SB-X (pi)  \
# 0         NaN        8.6        NaN        NaN        NaN        NaN
# 1        -3.3        3.8        NaN        NaN        NaN        NaN
# 2         5.0       -5.4        NaN       -7.2        NaN        NaN
# 11       -6.0        7.3        0.5        NaN        NaN        NaN
# 9         9.1       -3.9        0.1        NaN        NaN        NaN
#
#     SI-X (pi)  SL-X (pi)  XX-X (pi)  CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  \
# 0        10.3       -6.3        NaN       -1.0        NaN        NaN
# 1         8.4       -1.3        NaN        2.3        NaN       -5.9
# 2        -9.9        3.5        NaN        NaN        NaN       -6.3
# 11        NaN       -0.6        NaN        5.9        NaN       -8.7
# 9        -8.9        5.4        NaN        1.4        NaN       -9.0
#
#     FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  \
# 0         4.9        NaN        NaN        NaN        NaN        0.6
# 1         8.5        NaN        NaN        NaN        NaN        6.2
# 2         7.5        NaN        2.0        NaN        NaN        2.9
# 11        9.1        4.6        NaN        NaN        NaN        NaN
# 9         8.1        5.7        NaN        NaN        NaN        4.0
#
#     SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  wCU (pi)  wFA (pi)  wFC (pi)  \
# 0        -4.2        NaN      12.9       NaN       NaN      -0.4       NaN
# 1         2.5        NaN       9.0       NaN       1.7      17.2       NaN
# 2         2.3        NaN       NaN       NaN      -3.1      12.2       NaN
# 11       -0.8        NaN      10.1       NaN       3.2      11.6       0.7
# 9        -0.1        NaN       0.2       NaN      10.2       5.3       7.4
#
#     wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  wSL (pi)  wXX (pi)  wCH/C (pi)  \
# 0        NaN       NaN       NaN      -5.6      24.5       NaN        3.19
# 1        NaN       NaN       NaN       7.4       3.0       NaN        1.17
# 2        3.4       NaN       NaN      16.6       5.6       NaN         NaN
# 11       NaN       NaN       NaN       NaN      -1.1       NaN        1.37
# 9        NaN       NaN       NaN       3.5      -1.2       NaN        0.06
#
#     wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  \
# 0          NaN         NaN       -0.03         NaN         NaN         NaN
# 1          NaN        1.41        1.83         NaN         NaN         NaN
# 2          NaN       -0.96        0.94         NaN         1.5         NaN
# 11         NaN        0.98        0.89        0.20         NaN         NaN
# 9          NaN        1.43        0.73        2.65         NaN         NaN
#
#     wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  \
# 0          NaN       -2.66        2.16         NaN          0.341
# 1          NaN        1.27        0.71         NaN          0.326
# 2          NaN        2.77        0.81         NaN          0.330
# 11         NaN         NaN       -0.29         NaN          0.293
# 9          NaN        0.60       -0.23         NaN          0.285
#
#     Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  \
# 0           0.628        0.490            0.549            0.795
# 1           0.660        0.515            0.496            0.798
# 2           0.679        0.511            0.576            0.822
# 11          0.685        0.488            0.529            0.781
# 9           0.630        0.464            0.579            0.885
#
#     Contact% (pi)  Zone% (pi)  Pace (pi)  FRM  K/9+  BB/9+  K/BB+  H/9+  \
# 0           0.712       0.518       19.6  0.0   133     63    210    84
# 1           0.715       0.567       16.6  3.4   124     53    235    82
# 2           0.746       0.518       18.6 -1.4   118     75    157    74
# 11          0.705       0.497       17.8 -0.2   125    104    120    87
# 9           0.794       0.518       16.4 -0.3    91     67    136    95
#
#     HR/9+  AVG+  WHIP+  BABIP+  LOB%+  K%+  BB%+  LD%+  GB%+  FB%+  HR/FB%+  \
# 0      41    88     79     107    111  143    68   109   104    90       54
# 1      61    85     74      96    111  133    57    95   110    92       76
# 2      80    78     74      84    112  127    81    93    99   105       87
# 11     63    89     91     102    103  129   107    97    98   104       70
# 9      60    96     87      97    104   95    70    99   106    94       64
#
#     Pull%+  Cent%+  Oppo%+  Soft%+  Med%+  Hard%+    EV    LA  Barrels  \
# 0      108      90     101     105    111      79  86.5   9.6       24
# 1       95     102     106     112    107      82  87.4  12.0       32
# 2       87     115     100     131     95      92  86.7  13.0       42
# 11      97      92     117     109     99      97  88.3  15.3       29
# 9       95     114      88      96    103      97  88.5  10.7       48
#
#     Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xERA  botERA  \
# 0     0.056  114.4      134     0.312     430  0.182  0.323  2.79    3.34
# 1     0.067  113.0      162     0.337     481  0.175  0.321  2.72    3.26
# 2     0.083  114.3      167     0.332     503  0.144  0.273  2.85    2.97
# 11    0.062  115.4      165     0.354     466  0.145  0.289  3.31    3.50
# 9     0.080  115.1      233     0.390     598  0.187  0.281  3.74    4.29
#
#     botOvr CH  botStf CH  botCmd CH  botOvr CU  botStf CU  botCmd CU  \
# 0        56.0       48.0       61.0        NaN        NaN        NaN
# 1        66.0       68.0       56.0        NaN        NaN        NaN
# 2         NaN        NaN        NaN       48.0       62.0       43.0
# 11       61.0       65.0       54.0        NaN        NaN        NaN
# 9        47.0       44.0       52.0       59.0       56.0       54.0
#
#     botOvr FA  botStf FA  botCmd FA  botOvr SI  botStf SI  botCmd SI  \
# 0        58.0       48.0       62.0       57.0       50.0       58.0
# 1        60.0       56.0       59.0       52.0       53.0       60.0
# 2        67.0       59.0       66.0       64.0       65.0       51.0
# 11       61.0       60.0       56.0        NaN        NaN        NaN
# 9        49.0       42.0       56.0       50.0       40.0       53.0
#
#     botOvr SL  botStf SL  botCmd SL  botOvr KC  botStf KC  botCmd KC  \
# 0        59.0       46.0       58.0        NaN        NaN        NaN
# 1        54.0       52.0       56.0       60.0       46.0       62.0
# 2        64.0       66.0       58.0        NaN        NaN        NaN
# 11       53.0       66.0       46.0       52.0       47.0       50.0
# 9        45.0       39.0       47.0        NaN        NaN        NaN
#
#     botOvr FC  botStf FC  botCmd FC  botOvr FS  botStf FS  botCmd FS  botOvr  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN      60
# 1         NaN        NaN        NaN        NaN        NaN        NaN      61
# 2        45.0       61.0       47.0       52.0       46.0       58.0      64
# 11       51.0       55.0       56.0        NaN        NaN        NaN      58
# 9        53.0       37.0       59.0       48.0       34.0       56.0      50
#
#     botStf  botCmd  botxRV100  Stf+ CH  Loc+ CH  Pit+ CH  Stf+ CU  Loc+ CU  \
# 0       48      64      -0.49    100.0    111.0    110.0      NaN      NaN
# 1       59      61      -0.55    127.0     98.0    124.0      NaN      NaN
# 2       59      60      -0.74      NaN      NaN      NaN    126.0     88.0
# 11      62      54      -0.38    115.0     92.0    110.0      NaN      NaN
# 9       42      54       0.14     77.0     89.0     72.0    107.0     99.0
#
#     Pit+ CU  Stf+ FA  Loc+ FA  Pit+ FA  Stf+ SI  Loc+ SI  Pit+ SI  Stf+ SL  \
# 0       NaN     97.0    108.0    100.0     95.0    109.0    108.0    114.0
# 1       NaN    104.0    104.0    107.0    111.0    100.0    108.0    108.0
# 2     106.0    109.0    110.0    118.0    117.0    103.0    122.0    108.0
# 11      NaN    110.0    101.0    111.0      NaN      NaN      NaN    124.0
# 9     103.0     93.0    103.0     96.0     94.0    100.0     97.0    102.0
#
#     Loc+ SL  Pit+ SL  Stf+ KC  Loc+ KC  Pit+ KC  Stf+ FC  Loc+ FC  Pit+ FC  \
# 0     114.0    120.0      NaN      NaN      NaN      NaN      NaN      NaN
# 1      96.0    111.0     98.0    102.0    101.0      NaN      NaN      NaN
# 2     109.0    117.0      NaN      NaN      NaN     97.0     95.0     96.0
# 11    102.0    117.0     98.0    108.0    104.0     93.0     98.0    100.0
# 9      90.0     95.0      NaN      NaN      NaN     93.0    114.0    108.0
#
#     Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  Stf+ FO  Loc+ FO  \
# 0       NaN      NaN      NaN     104        111        110      NaN      NaN
# 1       NaN      NaN      NaN     112        100        112      NaN      NaN
# 2      94.0    101.0     91.0     110        104        113      NaN      NaN
# 11      NaN      NaN      NaN     110         99        110      NaN      NaN
# 9      86.0    100.0     78.0      97        100         97      NaN      NaN
#
#     Pit+ FO
# 0       NaN
# 1       NaN
# 2       NaN
# 11      NaN
# 9       NaN

# %%
data.columns
# Out:
# Index(['IDfg', 'Season', 'Name', 'Team', 'Age', 'W', 'L', 'WAR', 'ERA', 'G',
#        ...
#        'Pit+ FC', 'Stf+ FS', 'Loc+ FS', 'Pit+ FS', 'Stuff+', 'Location+',
#        'Pitching+', 'Stf+ FO', 'Loc+ FO', 'Pit+ FO'],
#       dtype='object', length=393)

# %%
pitchers_data = data[['Name','xERA', 'EV', 'Contact%', 'AVG', 'K%', 'FBv', 'CTv', 'CBv', 'CHv', 'SFv', 'KNv', 'Location+']]
pitchers_data.head()
# Out:
#             Name  xERA    EV  Contact%    AVG     K%   FBv   CTv   CBv   CHv  \
# 0     Chris Sale  2.79  86.5     0.711  0.215  0.321  94.8   NaN   NaN  86.9
# 1   Tarik Skubal  2.72  87.4     0.717  0.200  0.303  96.8   NaN  78.5  86.3
# 2   Zack Wheeler  2.85  86.7     0.747  0.191  0.285  95.1  91.1  81.8   NaN
# 11   Cole Ragans  3.31  88.3     0.705  0.212  0.293  95.4  91.0  80.8  84.8
# 9      Seth Lugo  3.74  88.5     0.795  0.227  0.217  92.2  89.9  79.8  87.5
#
#      SFv  KNv  Location+
# 0    NaN  NaN        111
# 1    NaN  NaN        100
# 2   86.2  NaN        104
# 11   NaN  NaN         99
# 9   85.8  NaN        100

# %%
# Displaying the number of missing input per row
missing_data = pitchers_data.isna()
for column in pitchers_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Name
# Name
# False    58
# Name: count, dtype: int64
#
# xERA
# xERA
# False    58
# Name: count, dtype: int64
#
# EV
# EV
# False    58
# Name: count, dtype: int64
#
# Contact%
# Contact%
# False    58
# Name: count, dtype: int64
#
# AVG
# AVG
# False    58
# Name: count, dtype: int64
#
# K%
# K%
# False    58
# Name: count, dtype: int64
#
# FBv
# FBv
# False    58
# Name: count, dtype: int64
#
# CTv
# CTv
# False    58
# Name: count, dtype: int64
#
# CBv
# CBv
# False    58
# Name: count, dtype: int64
#
# CHv
# CHv
# False    58
# Name: count, dtype: int64
#
# Location+
# Location+
# False    58
# Name: count, dtype: int64
#
# FB_Grouped
# FB_Grouped
# False    58
# Name: count, dtype: int64

# %%
# Dropping KNv and SFv because both variables are missing a lot of inputs, and it would be too difficult to make an appropriate assumption
pitchers_data = pitchers_data.drop(['KNv', 'SFv'], axis=1)
pitchers_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Dropping KNv and SFv because both variables are missing a lot of inputs, and it would be too difficult to make an appropriate assumption
# ----> 2 pitchers_data = pitchers_data.drop(['KNv', 'SFv'], axis=1)
#       3 pitchers_data.head()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['KNv', 'SFv'] not found in axis"

# %%
# Dropping no name, since it is a string variable
no_name_df = pitchers_data
no_name_df = no_name_df.drop('Name', axis=1)
print(no_name_df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 4
#       2 no_name_df = pitchers_data
#       3 no_name_df = no_name_df.drop('Name', axis=1)
# ----> 4 print(no_name_df.corr())
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1747, in BlockManager._interleave(self, dtype, na_value)
#    1741 rl = blk.mgr_locs
#    1742 if blk.is_extension:
#    1743     # Avoid implicit conversion of extension blocks to object
#    1744
#    1745     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1746     # attribute "to_numpy"
# -> 1747     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1748         dtype=dtype,
#    1749         na_value=na_value,
#    1750     )
#    1751 else:
#    1752     arr = blk.get_values(dtype)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arrays/base.py:568, in ExtensionArray.to_numpy(self, dtype, copy, na_value)
#     539 def to_numpy(
#     540     self,
#     541     dtype: npt.DTypeLike | None = None,
#     542     copy: bool = False,
#     543     na_value: object = lib.no_default,
#     544 ) -> np.ndarray:
#     545     """
#     546     Convert to a NumPy ndarray.
#     547
#    (...)
#     566     numpy.ndarray
#     567     """
# --> 568     result = np.asarray(self, dtype=dtype)
#     569     if copy or na_value is not lib.no_default:
#     570         result = result.copy()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arrays/_mixins.py:81, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      78 @wraps(meth)
#      79 def method(self, *args, **kwargs):
#      80     if self.ndim == 1:
# ---> 81         return meth(self, *args, **kwargs)
#      83     flags = self._ndarray.flags
#      84     flat = self.ravel("K")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:1664, in Categorical.__array__(self, dtype, copy)
#    1662 ret = take_nd(self.categories._values, self._codes)
#    1663 if dtype and np.dtype(dtype) != self.categories.dtype:
# -> 1664     return np.asarray(ret, dtype)
#    1665 # When we're a Categorical[ExtensionArray], like Interval,
#    1666 # we need to ensure __array__ gets all the way to an
#    1667 # ndarray.
#    1668 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'Third_Quartile'

# %%
# Calculating a ratio to calculate cutter speeds for na values
throws_ctv = pitchers_data[['FBv','CTv']].dropna()
print(throws_ctv['FBv'].mean())
print(throws_ctv['CTv'].mean())
ctv_fb_ratio = throws_ctv['CTv'].mean() / throws_ctv['FBv'].mean()
print(ctv_fb_ratio)
pitchers_data['CTv'] = pitchers_data['CTv'].fillna(pitchers_data['FBv']*ctv_fb_ratio)
pitchers_data['CTv'] = pitchers_data['CTv'].round(1)
pitchers_data.head()
# Out:
# 93.74310344827587
# 89.37241379310345
# 0.9533758805245443
#             Name  xERA    EV  Contact%    AVG     K%   FBv   CTv   CBv   CHv  \
# 0     Chris Sale  2.79  86.5     0.711  0.215  0.321  94.8  90.4  79.3  86.9
# 1   Tarik Skubal  2.72  87.4     0.717  0.200  0.303  96.8  92.3  78.5  86.3
# 2   Zack Wheeler  2.85  86.7     0.747  0.191  0.285  95.1  91.1  81.8  85.6
# 11   Cole Ragans  3.31  88.3     0.705  0.212  0.293  95.4  91.0  80.8  84.8
# 9      Seth Lugo  3.74  88.5     0.795  0.227  0.217  92.2  89.9  79.8  87.5
#
#     Location+       FB_Grouped
# 0         111   Third_Quartile
# 1         100  Fourth_Quartile
# 2         104   Third_Quartile
# 11         99  Fourth_Quartile
# 9         100   First_Quartile

# %%
# Replacing na values for CBv and CHv with the mean value
cbv_mean = pitchers_data['CBv'].mean()
chv_mean = pitchers_data['CHv'].mean()
pitchers_data['CBv'] = pitchers_data['CBv'].fillna(cbv_mean)
pitchers_data['CHv'] = pitchers_data['CHv'].fillna(chv_mean)
pitchers_data['CBv'] = pitchers_data['CBv'].round(1)
pitchers_data['CHv'] = pitchers_data['CHv'].round(1)
pitchers_data.head()
# Out:
#             Name  xERA    EV  Contact%    AVG     K%   FBv   CTv   CBv   CHv  \
# 0     Chris Sale  2.79  86.5     0.711  0.215  0.321  94.8  90.4  79.3  86.9
# 1   Tarik Skubal  2.72  87.4     0.717  0.200  0.303  96.8  92.3  78.5  86.3
# 2   Zack Wheeler  2.85  86.7     0.747  0.191  0.285  95.1  91.1  81.8  85.6
# 11   Cole Ragans  3.31  88.3     0.705  0.212  0.293  95.4  91.0  80.8  84.8
# 9      Seth Lugo  3.74  88.5     0.795  0.227  0.217  92.2  89.9  79.8  87.5
#
#     Location+       FB_Grouped
# 0         111   Third_Quartile
# 1         100  Fourth_Quartile
# 2         104   Third_Quartile
# 11         99  Fourth_Quartile
# 9         100   First_Quartile

# %%
# Creating a csv file of the complete DataFrame
pitchers_data.to_csv('Pitchers_Data.csv', index=False)

# %% [markdown]
# # Examining Data Through Graphs and Statistics

# %%
# Examining fastball velocity and xERA through a scatter plot
plt.scatter(pitchers_data['FBv'], pitchers_data['xERA'])
plt.title("Fastball Velocity and xERA Scatter Plot")
plt.xlabel('Fastball Velocity (mph)')
plt.ylabel('xERA')
plt.show()

# %%
# Examining Location+ and xERA through a scatter plot
plt.scatter(pitchers_data['Location+'], pitchers_data['xERA'])
plt.title('Location and xERA Scatter Plot')
plt.xlabel('Location+')
plt.ylabel('xERA')
plt.show()

# %%
# Examining xERA via fastball velocity
pitchers_data['FBv'].describe()
bins = [0, 92.45, 93.75, 95.1, 98]
labels = ['First_Quartile', 'Second_Quartile', 'Third_Quartile', 'Fourth_Quartile']
pitchers_data['FB_Grouped'] = pd.cut(
    pitchers_data['FBv'],
    bins=bins,
    labels=labels,
    include_lowest = True
    )
bar_graph_fb_grouped_df = pitchers_data.copy()
bar_graph_fb_grouped_df = bar_graph_fb_grouped_df.sort_values(by='FBv', ascending=True)
bar_graph_fb_grouped_df.reset_index(drop=True)
print(bar_graph_fb_grouped_df.head())

print()
print()
print()

plt.bar(bar_graph_fb_grouped_df['FB_Grouped'], pitchers_data['xERA'], )
plt.title("Quartile of Pitchers and xERA")
plt.xlabel("Quartiles")
plt.ylabel("xERA")
plt.show()
# Out:
#               Name  xERA    EV  Contact%    AVG     K%   FBv   CTv   CBv  \
# 34  Tyler Anderson  4.37  87.2     0.741  0.231  0.186  89.4  84.2  71.7
# 54   Austin Gomber  5.05  90.2     0.821  0.271  0.167  90.5  86.3  77.6
# 31   Jose Quintana  4.52  88.0     0.801  0.233  0.188  90.8  86.6  77.6
# 45     Kyle Gibson  4.86  88.2     0.756  0.248  0.209  91.0  88.7  78.3
# 57  Patrick Corbin  5.52  90.8     0.788  0.294  0.182  91.5  85.5  79.3
#
#      CHv  Location+      FB_Grouped
# 34  79.0         96  First_Quartile
# 54  81.1        106  First_Quartile
# 31  85.8        101  First_Quartile
# 45  84.9        100  First_Quartile
# 57  81.1        102  First_Quartile

# %%
# Grouping by FB_Group and examining statistics
fb_by_groups = pitchers_data.groupby('FB_Grouped')['xERA']
fb_by_groups.describe()
# Out:
# /var/folders/y2/ffmphcn51c18jj38jsf88tyc0000gn/T/ipykernel_79414/445575765.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fb_by_groups = pitchers_data.groupby('FB_Grouped')['xERA']
#                  count      mean       std   min    25%   50%    75%   max
# FB_Grouped
# First_Quartile    15.0  4.168000  0.667631  3.21  3.700  4.03  4.595  5.52
# Second_Quartile   14.0  4.177857  0.455432  3.57  3.865  4.05  4.605  4.89
# Third_Quartile    15.0  3.813333  0.561855  2.79  3.605  3.75  4.295  4.82
# Fourth_Quartile   14.0  3.623571  0.488760  2.72  3.310  3.56  3.905  4.54

# %%
# Examing fastball velocity and EV through a scatter plot
plt.scatter(pitchers_data['FBv'], pitchers_data['EV'])
plt.title('Fastball Velocity and EV Scatter Plot')
plt.xlabel('Fastball Velocity (mph)')
plt.ylabel('Exit Velocity (mph)')
plt.show()

# %%
# Statistics on the different fastball groups and exit velocity
fb_by_groups = pitchers_data.groupby('FB_Grouped')['EV']
fb_by_groups.describe()
# Out:
# /var/folders/y2/ffmphcn51c18jj38jsf88tyc0000gn/T/ipykernel_79414/2217302547.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fb_by_groups = pitchers_data.groupby('FB_Grouped')['EV']
#                  count       mean       std   min     25%    50%     75%   max
# FB_Grouped
# First_Quartile    15.0  88.786667  0.994174  87.2  88.150  88.60  89.500  90.8
# Second_Quartile   14.0  88.757143  1.320090  85.7  88.400  88.75  89.600  90.5
# Third_Quartile    15.0  88.353333  1.319018  86.3  87.500  88.40  89.100  90.3
# Fourth_Quartile   14.0  88.578571  1.228619  86.2  87.625  88.75  89.525  90.4

# %% [markdown]
# # Conclusion
# * There is negative relationship between fastball velocity and expected earned runs allowed
# * It does appear that pitchers who throw their fastballs harder have a lower expected earned runs allowed because pitchers in the fourth quartile in fastball velocity have the lowest expected earned runs allowed, which follows the trend of the two variables having a negative correlation relationship
# * There appears to be no relationship between fastball velocity and exit velocity.
# * Lastly, there is no relationship between location and expected earned runs allowed.
